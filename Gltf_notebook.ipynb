# %%
from pathlib import Path
import json
from IPython.display import HTML

from gltf import model_to_gltf_script

import openstudio
openstudio.openStudioLongVersion()

# %%
# openstudio.Logger.instance().standardOutLogger().setLogLevel(openstudio.Debug)
m = openstudio.model.exampleModel()
m.getSpaces()[0].remove()
template = model_to_gltf_script(model=m)

# %%
HTML(template)
